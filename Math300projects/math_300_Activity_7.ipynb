# %%
name = "PI"
pi=3.14159265359
d=11
print(f"The constant {name} = {pi}, is aproximated to {d} decimal places.")
print(type(name))
print(type(pi))
print(type(d))
# Out:
# The constant PI = 3.14159265359, is aproximated to 11 decimal places.
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %%
list=[1,2,3,420,4,5,6]
sublistfirst= list[:3]
sublistlast= list[4:7]
sublistmiddle=list[3:4]
sublistback= list[::-1]
print(f"(a) {sublistfirst}")
print(f"(b) {sublistlast}")
print(f"(c) {sublistmiddle}")
print(f"(d) {sublistback}")
# Out:
# (a) [1, 2, 3]
# (b) [4, 5, 6]
# (c) [420]
# (c) [6, 5, 4, 420, 3, 2, 1]

# %%
sum=0
for i in range (11):
    sum=sum+i**2
    print(sum)

x=10
while x > 0:
    x=x-1
    print(x)
# Out:
# 0
# 1
# 5
# 14
# 30
# 55
# 91
# 140
# 204
# 285
# 385
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0
